# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Heart.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
#data cleaning
df.duplicated().sum()
# Out:
# 723

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Drop rows with missing values
df1 = df.dropna()

# %%
df1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
df1.shape
# Out:
# (302, 14)

# %%
# Remove unnecessary columns
df2 = df.drop(columns=["slope", "exang"])
df2
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  oldpeak  ca  thal  \
# 0     52    1   0       125   212    0        1      168      1.0   2     3
# 1     53    1   0       140   203    1        0      155      3.1   0     3
# 2     70    1   0       145   174    0        1      125      2.6   0     3
# 3     61    1   0       148   203    0        1      161      0.0   1     3
# 4     62    0   0       138   294    1        1      106      1.9   3     2
# ..   ...  ...  ..       ...   ...  ...      ...      ...      ...  ..   ...
# 723   68    0   2       120   211    0        0      115      1.5   0     2
# 733   44    0   2       108   141    0        1      175      0.6   0     2
# 739   52    1   0       128   255    0        1      161      0.0   1     3
# 843   59    1   3       160   273    0        0      125      0.0   0     2
# 878   54    1   0       120   188    0        1      113      1.4   1     3
#
#      target
# 0         0
# 1         0
# 2         0
# ...

# %%
#data integrationa
df3=df[['age','sex','cp','thal']]
df3
# Out:
#      age  sex  cp  thal
# 0     52    1   0     3
# 1     53    1   0     3
# 2     70    1   0     3
# 3     61    1   0     3
# 4     62    0   0     2
# ..   ...  ...  ..   ...
# 723   68    0   2     2
# 733   44    0   2     2
# 739   52    1   0     3
# 843   59    1   3     2
# 878   54    1   0     3
#
# [302 rows x 4 columns]

# %%
df4=df[['age','trestbps','ca']]
df4
# Out:
#      age  trestbps  ca
# 0     52       125   2
# 1     53       140   0
# 2     70       145   0
# 3     61       148   1
# 4     62       138   3
# ..   ...       ...  ..
# 723   68       120   0
# 733   44       108   0
# 739   52       128   1
# 843   59       160   0
# 878   54       120   1
#
# [302 rows x 3 columns]

# %%
merge=pd.merge(df3,df4,on='age',how='inner')
merge
# Out:
#       age  sex  cp  thal  trestbps  ca
# 0      52    1   0     3       125   2
# 1      52    1   0     3       128   0
# 2      52    1   0     3       134   1
# 3      52    1   0     3       118   0
# 4      52    1   0     3       138   4
# ...   ...  ...  ..   ...       ...  ..
# 3057   35    1   0     3       120   0
# 3058   35    1   0     3       138   0
# 3059   35    1   0     3       122   0
# 3060   35    1   0     3       126   0
# 3061   74    0   1     2       120   1
#
# [3062 rows x 6 columns]

# %%
#error correction
df['oldpeak']=df['oldpeak'].astype(int)
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0        1
# 1     53    1   0       140   203    1        0      155      1        3
# 2     70    1   0       145   174    0        1      125      1        2
# 3     61    1   0       148   203    0        1      161      0        0
# 4     62    0   0       138   294    1        1      106      0        1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0        1
# 733   44    0   2       108   141    0        1      175      0        0
# 739   52    1   0       128   255    0        1      161      1        0
# 843   59    1   3       160   273    0        0      125      0        0
# 878   54    1   0       120   188    0        1      113      0        1
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
#transformation for age if age > convert it to one
df['age']=df['age'].apply(lambda  x :1 if x>50 else 0 )
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      1    1   0       125   212    0        1      168      0        1
# 1      1    1   0       140   203    1        0      155      1        3
# 2      1    1   0       145   174    0        1      125      1        2
# 3      1    1   0       148   203    0        1      161      0        0
# 4      1    0   0       138   294    1        1      106      0        1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723    1    0   2       120   211    0        0      115      0        1
# 733    0    0   2       108   141    0        1      175      0        0
# 739    1    1   0       128   255    0        1      161      1        0
# 843    1    1   3       160   273    0        0      125      0        0
# 878    1    1   0       120   188    0        1      113      0        1
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
#model building
from sklearn.model_selection import train_test_split
x=df['chol']
x
# Out:
# 0      212
# 1      203
# 2      174
# 3      203
# 4      294
#       ...
# 723    211
# 733    141
# 739    255
# 843    273
# 878    188
# Name: chol, Length: 302, dtype: int64

# %%
x.shape
# Out:
# (302,)

# %%
x=x.values
x=x.reshape(302,1)

# %%
y=df['target']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 723    1
# 733    1
# 739    0
# 843    0
# 878    0
# Name: target, Length: 302, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()

# %%
logreg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report,confusion_matrix
y_pred=logreg.predict(x_test)

# %%
print(confusion_matrix(y_test,y_pred))

print(classification_report(y_test,y_pred))
# Out:
# [[12 24]
#  [12 43]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.33      0.40        36
#            1       0.64      0.78      0.70        55
#
#     accuracy                           0.60        91
#    macro avg       0.57      0.56      0.55        91
# weighted avg       0.59      0.60      0.58        91

# %%
confusion_matrix(y_test,y_pred)
cm=confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>
