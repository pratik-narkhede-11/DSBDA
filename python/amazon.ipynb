# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Amazonbookreviews.csv")
df
# Out:
#          reviewerID      asin reviewername  helpful  \
# 0    A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1    A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2    A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3    A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4    A1SUAM1J3GNN3B     123.0      PRANOTI        3
# 5   BA2345WERSDFRER  236789.0      SHALINI        3
# 6   CADERVG3450EREW       NaN       SNEHAL        3
# 7   ASDF345671QWERT  224442.0       SHIKHA        3
# 8     MNHJ879WERFGH   98767.0       AKSHAY        2
# 9    1234ZSDFREQWEG   78761.0       SATISH        2
# 10   9345GHIKLFLLED  321456.0         RAJU        2
# 11              NaN  876231.0        ROHIT        2
# 12   HGKIUYE345SFDG     987.0        MOHIT        2
# 13  NIKRT2398701222     234.0       NILESH        2
# 14   MAHI2348900122     124.0      KAILASH        2
# 15   LIHJKD87634O21     156.0        SONAM        2
# 16  SISISWER4657893     876.0       RAJESH        2
# ...

# %%
#
df1=df[['reviewerID','asin','reviewername','reviewerText']].loc[0:15]
df1
# Out:
#          reviewerID      asin reviewername  \
# 0    A2SUAM1J3GNN3B   23456.0        SNEHA
# 1    A2SUAN1J3GNN0C  879877.0      KARTHII
# 2    A2SUAN1J3GNN7B   23456.0     SHASHANK
# 3    A5SUAN1J3GNN9B   67578.0        NITIN
# 4    A1SUAM1J3GNN3B     123.0      PRANOTI
# 5   BA2345WERSDFRER  236789.0      SHALINI
# 6   CADERVG3450EREW       NaN       SNEHAL
# 7   ASDF345671QWERT  224442.0       SHIKHA
# 8     MNHJ879WERFGH   98767.0       AKSHAY
# 9    1234ZSDFREQWEG   78761.0       SATISH
# 10   9345GHIKLFLLED  321456.0         RAJU
# 11              NaN  876231.0        ROHIT
# 12   HGKIUYE345SFDG     987.0        MOHIT
# 13  NIKRT2398701222     234.0       NILESH
# 14   MAHI2348900122     124.0      KAILASH
# 15   LIHJKD87634O21     156.0        SONAM
#
#                                          reviewerText
# 0   I bought this for my husband who plays the pia...
# 1                                   good book to read
# 2                                           high cost
# ...

# %%
df2=df[['reviewerID','asin','reviewername','reviewerText']].loc[16:30]
df2
# Out:
#          reviewerID     asin reviewername        reviewerText
# 16  SISISWER4657893    876.0       RAJESH       money is dis
# 17   MIKI23412341QW    123.0       SALMAN    stare the raeder
# 18   AAAJI37DFG378I    987.0       PANKAJ     reader is giood
# 19   FAJI234GAJI987  22456.0        DIPTI             faskjas
# 20    VABI9876ERTT1   9876.0       MANISH               fdghi
# 21   NIKI12NIKI1231   3451.0       SHREYA           dvdasaewb
# 22   MIKISDF1232XAD    879.0    AISHWARYA                 NA
# 23     GHAU8768QWER    321.0       SUMEET                 NA
# 24   NIKI12NIKI1231      2.0      PRAJWAL                 NA
# 25   MIKISDF1232XAD      1.0        JACOB         0.888888888
# 26     GHAU8768QWER     23.0       MARYLS         9.666666667
# 27  BA2345WERSDFRER     11.0        CHRIS             helpful
# 28  CADERVG3450EREW     11.0       MORRIS       staff is good
# 29  ASDF345671QWERT     23.0        HARRY  good buy for money
# ...

# %%
df3=df[['reviewerID','asin','reviewername','reviewerText']].loc[31:44]
df3
# Out:
#          reviewerID     asin reviewername           reviewerText
# 31   1234ZSDFREQWEG     21.0       VARSHA       stare the raeder
# 32   9345GHIKLFLLED  12212.0     SHRADDHA        reader is giood
# 33              NaN   2121.0         SAIF                faskjas
# 34   HGKIUYE345SFDG  21212.0       KRISSH                  fdghi
# 35  NIKRT2398701222  21221.0         NEIL               8.78E+21
# 36   MAHI2348900122  22245.0      KANGANA                  67667
# 37   LIHJKD87634O21    678.0        KHANN                3434567
# 38  SISISWER4657893    111.0        RIYAA                   098O
# 39     8786112GHAUI    223.0          NaN              GOOD LUCK
# 40      67FDASAA123   2312.0      NANAJJI            BYE MY LOVE
# 41        ASWER1234   1222.0       PREETI                LOVE U
# 42       QWCVFED123  11111.0        DHONI             HELLO DEAR
# 43      123LKIUHNFG   9800.0         MAHI  DAER PLEASE READ BOOK
# ...

# %%
df4=df[['reviewerID','asin','reviewername','reviewerText']]
df4
# Out:
#          reviewerID      asin reviewername  \
# 0    A2SUAM1J3GNN3B   23456.0        SNEHA
# 1    A2SUAN1J3GNN0C  879877.0      KARTHII
# 2    A2SUAN1J3GNN7B   23456.0     SHASHANK
# 3    A5SUAN1J3GNN9B   67578.0        NITIN
# 4    A1SUAM1J3GNN3B     123.0      PRANOTI
# 5   BA2345WERSDFRER  236789.0      SHALINI
# 6   CADERVG3450EREW       NaN       SNEHAL
# 7   ASDF345671QWERT  224442.0       SHIKHA
# 8     MNHJ879WERFGH   98767.0       AKSHAY
# 9    1234ZSDFREQWEG   78761.0       SATISH
# 10   9345GHIKLFLLED  321456.0         RAJU
# 11              NaN  876231.0        ROHIT
# 12   HGKIUYE345SFDG     987.0        MOHIT
# 13  NIKRT2398701222     234.0       NILESH
# 14   MAHI2348900122     124.0      KAILASH
# 15   LIHJKD87634O21     156.0        SONAM
# 16  SISISWER4657893     876.0       RAJESH
# 17   MIKI23412341QW     123.0       SALMAN
# 18   AAAJI37DFG378I     987.0       PANKAJ
# 19   FAJI234GAJI987   22456.0        DIPTI
# 20    VABI9876ERTT1    9876.0       MANISH
# ...

# %%
df5=df[['overallRating','Summary']]
df5
# Out:
#     overallRating                Summary
# 0             4.0            SUBWAY SURF
# 1             3.0                 PILOT
# 2             2.5        DRIVE IN HEAVEN
# 3             2.2          SPORTS HEAVEN
# 4             3.0       HEAVEN OF PEARLS
# 5             3.0              GODS GIFT
# 6             3.0            GODESS LIFE
# 7             3.0            LIFE OF PIE
# 8             3.0  INDIA A MASSIVE POWER
# 9             5.0           DATA IS DATA
# 10            4.0  INDIA A MASSIVE POWER
# 11            4.0           FRIENDS HELP
# 12            4.0           MOTIVATIONAL
# 13            3.0            DARK KNIGHT
# 14            3.0           HELL OF HELL
# 15            3.0                   DEAA
# 16            3.0            DEAR TO ALL
# 17            2.0                MOTHER
# 18            2.0           WINE OF WINE
# 19            2.0   INDIA IS MY COUNTRY
# 20            2.0           ONE FOR ALLL
# 21            4.0           DATA IS DATA
# ...

# %%
merge1=pd.concat([df1,df2,df3])
merge1
# Out:
#          reviewerID      asin reviewername  \
# 0    A2SUAM1J3GNN3B   23456.0        SNEHA
# 1    A2SUAN1J3GNN0C  879877.0      KARTHII
# 2    A2SUAN1J3GNN7B   23456.0     SHASHANK
# 3    A5SUAN1J3GNN9B   67578.0        NITIN
# 4    A1SUAM1J3GNN3B     123.0      PRANOTI
# 5   BA2345WERSDFRER  236789.0      SHALINI
# 6   CADERVG3450EREW       NaN       SNEHAL
# 7   ASDF345671QWERT  224442.0       SHIKHA
# 8     MNHJ879WERFGH   98767.0       AKSHAY
# 9    1234ZSDFREQWEG   78761.0       SATISH
# 10   9345GHIKLFLLED  321456.0         RAJU
# 11              NaN  876231.0        ROHIT
# 12   HGKIUYE345SFDG     987.0        MOHIT
# 13  NIKRT2398701222     234.0       NILESH
# 14   MAHI2348900122     124.0      KAILASH
# 15   LIHJKD87634O21     156.0        SONAM
# 16  SISISWER4657893     876.0       RAJESH
# 17   MIKI23412341QW     123.0       SALMAN
# 18   AAAJI37DFG378I     987.0       PANKAJ
# 19   FAJI234GAJI987   22456.0        DIPTI
# 20    VABI9876ERTT1    9876.0       MANISH
# ...

# %%
merge2=pd.concat([df4,df5])
merge2
# Out:
#         reviewerID      asin reviewername  \
# 0   A2SUAM1J3GNN3B   23456.0        SNEHA
# 1   A2SUAN1J3GNN0C  879877.0      KARTHII
# 2   A2SUAN1J3GNN7B   23456.0     SHASHANK
# 3   A5SUAN1J3GNN9B   67578.0        NITIN
# 4   A1SUAM1J3GNN3B     123.0      PRANOTI
# ..             ...       ...          ...
# 40             NaN       NaN          NaN
# 41             NaN       NaN          NaN
# 42             NaN       NaN          NaN
# 43             NaN       NaN          NaN
# 44             NaN       NaN          NaN
#
#                                          reviewerText  overallRating  \
# 0   I bought this for my husband who plays the pia...            NaN
# 1                                   good book to read            NaN
# 2                                           high cost            NaN
# 3                                     good useof book            NaN
# 4                             I m happy with the book            NaN
# ...

# %%
sort_values=df.sort_values('overallRating',ascending=False)
sort_values
# Out:
#          reviewerID      asin reviewername  helpful  \
# 9    1234ZSDFREQWEG   78761.0       SATISH        2
# 0    A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 21   NIKI12NIKI1231    3451.0       SHREYA        2
# 43      123LKIUHNFG    9800.0         MAHI        2
# 42       QWCVFED123   11111.0        DHONI        2
# 41        ASWER1234    1222.0       PREETI        2
# 40      67FDASAA123    2312.0      NANAJJI        3
# 31   1234ZSDFREQWEG      21.0       VARSHA        3
# 30    MNHJ879WERFGH   21221.0         JOHN        3
# 29  ASDF345671QWERT      23.0        HARRY        3
# 28  CADERVG3450EREW      11.0       MORRIS        3
# 27  BA2345WERSDFRER      11.0        CHRIS        3
# 26     GHAU8768QWER      23.0       MARYLS        3
# 25   MIKISDF1232XAD       1.0        JACOB        3
# 24   NIKI12NIKI1231       2.0      PRAJWAL        3
# 23     GHAU8768QWER     321.0       SUMEET        2
# 22   MIKISDF1232XAD     879.0    AISHWARYA        2
# ...

# %%
transpose=df.transpose()
transpose
# Out:
#                                                                0   \
# reviewerID                                         A2SUAM1J3GNN3B
# asin                                                        23456
# reviewername                                                SNEHA
# helpful                                                         2
# reviewerText    I bought this for my husband who plays the pia...
# overallRating                                                   4
# Summary                                               SUBWAY SURF
# UnixreviewTime                                                NaN
# reviewTime                                                    NaN
#
#                                1                2                3   \
# reviewerID         A2SUAN1J3GNN0C   A2SUAN1J3GNN7B   A5SUAN1J3GNN9B
# asin                       879877            23456            67578
# reviewername              KARTHII         SHASHANK            NITIN
# ...

# %%
shape=df.shape
shape
# Out:
# (45, 9)

# %%
pt=pd.pivot_table(df,index=['reviewerID','reviewername'],values='overallRating')
print(pt)
# Out:
#                               overallRating
# reviewerID      reviewername
# 1234ZSDFREQWEG  SATISH                  5.0
#                 VARSHA                  4.0
# 123LKIUHNFG     MAHI                    4.0
# 67FDASAA123     NANAJJI                 4.0
# 9345GHIKLFLLED  RAJU                    4.0
#                 SHRADDHA                3.0
# 987DFHGJI657    DDE                     4.0
# A1SUAM1J3GNN3B  PRANOTI                 3.0
# A2SUAM1J3GNN3B  SNEHA                   4.0
# A2SUAN1J3GNN0C  KARTHII                 3.0
# A2SUAN1J3GNN7B  SHASHANK                2.5
# A5SUAN1J3GNN9B  NITIN                   2.2
# AAAJI37DFG378I  PANKAJ                  2.0
# ASDF345671QWERT HARRY                   4.0
#                 SHIKHA                  3.0
# ASWER1234       PREETI                  4.0
# BA2345WERSDFRER CHRIS                   4.0
#                 SHALINI                 3.0
# CADERVG3450EREW MORRIS                  4.0
#                 SNEHAL                  3.0
# ...
